# %%
import pandas as pd
data = pd.read_csv('insurance.csv')

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import matplotlib.pyplot as plt 

plt.scatter(data['bmi'],data['charges'])
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.show()

# %%
plt.boxplot(data['children'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x259cf45c430>,
#   <matplotlib.lines.Line2D at 0x259cf45c1f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x259cf442e20>,
#   <matplotlib.lines.Line2D at 0x259cf4bfaf0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x259cf45caf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x259cef27bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x259cfa10610>],
#  'means': []}

# %%
plt.scatter(data['age'],data['charges'])
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
le1 = preprocessing.LabelEncoder()
le2 = preprocessing.LabelEncoder()
le3 = preprocessing.LabelEncoder()

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
X = data[['age','sex','bmi','children','smoker','region']]
X.head()
# Out:
#    age     sex     bmi  children smoker     region
# 0   19  female  27.900         0    yes  southwest
# 1   18    male  33.770         1     no  southeast
# 2   28    male  33.000         3     no  southeast
# 3   33    male  22.705         0     no  northwest
# 4   32    male  28.880         0     no  northwest

# %%
y = data['charges']
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
X['sex']=le1.fit_transform(X['sex'])
X['smoker']=le2.fit_transform(X['smoker'])
X['region']=le3.fit_transform(X['region'])
# Out:
# <ipython-input-66-c5d08f158071>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['sex']=le1.fit_transform(X['sex'])
# <ipython-input-66-c5d08f158071>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['smoker']=le2.fit_transform(X['smoker'])
# <ipython-input-66-c5d08f158071>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['region']=le3.fit_transform(X['region'])

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,train_size=0.9)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[19,0,27,0,1,3]])[0]
# Out:
# 24937.38361864614

# %%
lr.score(X_test,y_test)
# Out:
# 0.7498775968915009

# %%
lr.coef_
# Out:
# array([  254.25263731,  -227.56935922,   339.60235765,   515.82169891,
#        23886.68589975,  -382.08024728])
